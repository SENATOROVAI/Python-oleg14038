# %%
import pandas as pd

df = pd.read_csv("C:/Users/Oleg/Downloads/lesson_1_data (1).csv",
                 encoding="windows-1251",
                 sep=";")

df
# Out:
#        Номер     Дата создания       Дата оплаты  \
# 0    1062823  01.12.2019 10:50  01.12.2019 10:52
# 1    1062855  01.12.2019 20:53  01.12.2019 21:27
# 2    1062856  01.12.2019 21:43               NaN
# 3    1062880   03.12.2019 0:18               NaN
# 4    1062899  03.12.2019 21:43               NaN
# ..       ...               ...               ...
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  Title    Статус  Заработано  \
# 0                              Курс обучения «Эксперт»  Завершен    29597.50
# 1                              Курс обучения «Эксперт»  Завершен    17450.30
# 2                           Курс обучения «Специалист»   Отменен        0.00
# ...

# %%
# df.head(3)# выводим первые 3 столбца нашой таблицы
# Out:
#       Номер     Дата создания       Дата оплаты  \
# 0   1062823  01.12.2019 10:50  01.12.2019 10:52
# 1   1062855  01.12.2019 20:53  01.12.2019 21:27
# 2   1062856  01.12.2019 21:43               NaN
# 3   1062880   03.12.2019 0:18               NaN
# 4   1062899  03.12.2019 21:43               NaN
# 5   1062900  03.12.2019 21:49               NaN
# 6   1062911  04.12.2019 13:12               NaN
# 7   1062914  04.12.2019 14:57               NaN
# 8   1062915  04.12.2019 16:08               NaN
# 9   1062925  04.12.2019 21:51               NaN
# 10  1062927  04.12.2019 22:02               NaN
# 11  1062931  04.12.2019 23:11               NaN
# 12  1062938  05.12.2019 12:07  22.12.2019 12:29
# 13  1062940  05.12.2019 15:35  05.12.2019 15:40
# 14  1062947  05.12.2019 21:39  07.12.2019 13:35
# 15  1062948  05.12.2019 21:56               NaN
# 16  1062949  05.12.2019 21:57   06.12.2019 9:15
# 17  1062950  05.12.2019 22:06               NaN
# ...

# %%
# df.tail(1)# выводим последние столбцы
# Out:
#       namber       create_date      payment_date  \
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  title    status    maney  \
# 287  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен  2935.44
# 288                        Курс обучения «Консультант»   Отменен     0.00
# 289                        Курс обучения «Консультант»  Завершен  7423.92
# 290  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен  2935.44
# 291  Курс от Школы Диетологов. Повышение квалификац...  Завершен  9898.56
#
#                    city                    payment_system
# 287   Самарская область                      Яндекс.Касса
# 288                 NaN                               NaN
# ...

# %%
# df.shape # (292, 8) выводим 292 строки 8 колонок
# Out:
# (292, 8)

# %%
# df.dtypes # выводим типы данных
# Out:
# namber              int64
# create_date        object
# payment_date       object
# title              object
# status             object
# maney             float64
# city               object
# payment_system     object
# dtype: object

# %%
df.describe()  # анализирует данные
# Out:
#               Номер    Заработано
# count  2.920000e+02    292.000000
# mean   1.063745e+06   3397.615034
# std    4.438688e+02   5771.572829
# min    1.062823e+06      0.000000
# 25%    1.063608e+06      0.000000
# 50%    1.063698e+06   2935.440000
# 75%    1.063807e+06   2935.440000
# max    1.064796e+06  42750.000000

# %%
df.columns  # Вызывае название калоники
# Out:
# Index(['number', 'create_date', 'payment_date', 'title', 'status', 'money',
#        'city', 'payment_system'],
#       dtype='object')

# %%
df = df.rename(
    columns={
        "Номер": "number",
        "Дата создания": "create_date",
        "Дата оплаты": "payment_date",
        "Title": "title",
        "Статус": "status",
        "Заработано": "maney",
        "Город": "city",
        "Платежная система": "payment_system",
    })

# %%
df = df.rename(columns={"maney": "money"})
df = df.rename(columns={"Номер": "number"})
df
# Out:
#       number       create_date      payment_date  \
# 0    1062823  01.12.2019 10:50  01.12.2019 10:52
# 1    1062855  01.12.2019 20:53  01.12.2019 21:27
# 2    1062856  01.12.2019 21:43               NaN
# 3    1062880   03.12.2019 0:18               NaN
# 4    1062899  03.12.2019 21:43               NaN
# ..       ...               ...               ...
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  title    status     money  \
# 0                              Курс обучения «Эксперт»  Завершен  29597.50
# 1                              Курс обучения «Эксперт»  Завершен  17450.30
# 2                           Курс обучения «Специалист»   Отменен      0.00
# ...

# %%
all_maney = df.money.sum()  # Подсчитали общую сумму курсов
all_money
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 all_maney = df.money.sum()# Подсчитали общую сумму курсов
# ----> 2 all_money
#
# NameError: name 'all_money' is not defined

# %%
money_by_city = (df.groupby(["title", "city"], as_index=False).aggregate({
    "maney":
    "sum"
}).sort_values("maney", ascending=False))

# df.groupby('title', as_index=False) Эта строка группирует фрейм данных df по столбцу 'title'.
#  Функция groupby собирает все строки с одинаковым значением в столбце 'title' в отдельные группы.
# Параметр as_index=False гарантирует, что столбец 'title' не будет использоваться в качестве индекса в результирующем

# Функция groupby
# собирает все строки с одинаковым значением в столбце 'title' в отдельные группы. Параметр as_index=False гарантирует,
# что столбец 'title' не будет использоваться в качестве индекса в результирующем фрейме данных.

# aggregate({'maney': 'sum'})

# Эта строка применяет функцию агрегирования к каждой группе, вычисляя сумму столбца "maney" внутри каждой группы.
# Функция агрегирования используется для указания операции агрегирования и столбцов, к которым она должна быть применена.
# В этом случае он агрегирует столбец 'maney', используя функцию 'sum'.

# Функция sort_values
# позволяет вам указать столбец для сортировки (в данном случае "maney") и в каком порядке следует
# выполнять сортировку: по возрастанию (ascending=True) или по убыванию (ascending=False).

# %%
all_maney = df.money.sum()  # Подсчитали общую сумму курсов
all_maney
# Out:
# 992103.5900000001

# %%
df.money.sum()
# df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13016\2630032877.py in ?()
# ----> 1 df.money.sum()
#       2 #df
#
# c:\Users\Oleg\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'money'

# %%
# money = df.groupby(['title', 'city'], as_index=False) \
# .aggregate({'money': 'sum'}) \
# .sort_values("money", ascending=False)# сортируем ascending=False
# money

# %%
money.to_csv("money.csv", index=False)  # Сохраняем фаил

# %%
df = pd.read_csv("C:/Users/Oleg/Downloads/lesson_1_data (1).csv",
                 encoding="windows-1251",
                 sep=";")

df = df.rename(
    columns={
        "Номер": "number",
        "Дата создания": "create_date",
        "Дата оплаты": "payment_date",
        "Title": "title",
        "Статус": "status",
        "Заработано": "money",
        "Город": "city",
        "Платежная система": "payment_system",
    })

money_sum = (df.query("'status' == 'Завершен'").groupby(
    ["title", "city"], as_index=False).aggregate({
        "money": "sum",
        "number": "count"
    }).sort_values("money",
                   ascending=True).rename(columns={"number": "succes_orders"}))

money_sum.money.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 17
#       3 df = pd.read_csv('C:/Users/Oleg/Downloads/lesson_1_data (1).csv', encoding='windows-1251', sep = ';')
#       5 df  = df.rename(columns= {'Номер': 'number',
#       6             'Дата создания': 'create_date',
#       7             'Дата оплаты': 'payment_date',
#    (...)
#      11            'Город' : 'city',
#      12           'Платежная система': 'payment_system'})
# ---> 17 money_sum = df.query("'status' == 'Завершен'") \
#      18     .groupby(['title', 'city'], as_index=False) \
#      19     .aggregate({'money': 'sum', 'number': 'count'}) \
#      20     .sort_values("money", ascending=True).rename(columns={'number': 'succes_orders'} )
#      22 money_sum.money.sum()
#
# ...

# %%
money_sum.money.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 money_sum.money.sum()
#
# NameError: name 'money_sum' is not defined

# %%
money_by_city.to_csv("money_by_city.csv", index=False)

# %%
all_maney
# Out:
# 992103.5900000001
